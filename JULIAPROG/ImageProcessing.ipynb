# %%
using Images
progname = "Julia"
println(progname, " is starting... \nfinish.")
# Out:
# Julia is starting...
# finish.

# %%
vine = load("neko_vignetto.jpg") #load an image
# Out:
# 1080×1920 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(0.208,0.176,0.125)  …  RGB{N0f8}(0.204,0.196,0.145)
#  RGB{N0f8}(0.208,0.176,0.125)     RGB{N0f8}(0.204,0.196,0.145)
#  RGB{N0f8}(0.208,0.176,0.125)     RGB{N0f8}(0.204,0.196,0.145)
#  RGB{N0f8}(0.208,0.176,0.125)     RGB{N0f8}(0.204,0.196,0.145)
#  RGB{N0f8}(0.208,0.176,0.125)     RGB{N0f8}(0.204,0.196,0.145)
#  RGB{N0f8}(0.208,0.176,0.125)  …  RGB{N0f8}(0.204,0.196,0.145)
#  RGB{N0f8}(0.208,0.176,0.125)     RGB{N0f8}(0.204,0.196,0.145)
#  RGB{N0f8}(0.208,0.176,0.125)     RGB{N0f8}(0.204,0.196,0.145)
#  RGB{N0f8}(0.204,0.173,0.122)     RGB{N0f8}(0.196,0.188,0.137)
#  RGB{N0f8}(0.204,0.173,0.122)     RGB{N0f8}(0.2,0.192,0.141)
#  RGB{N0f8}(0.204,0.173,0.122)  …  RGB{N0f8}(0.204,0.196,0.145)
#  RGB{N0f8}(0.204,0.173,0.122)     RGB{N0f8}(0.208,0.2,0.149)
#  RGB{N0f8}(0.204,0.173,0.122)     RGB{N0f8}(0.204,0.196,0.145)
#  ⋮                             ⋱
# ...

# %%
println("typeof image : ", typeof(vine))
size(vine)
# Out:
# typeof image : Array{RGB{Normed{UInt8,8}},2}
# (1080, 1920)
